# %%
print("Hello world")
# Out:
# Hello world

# %%
import json

with open("polybOutput/imagenet_train_fixsize480_tau0.15_N3.json", 'r') as f:
    data = json.load(f)
with open("polybOutput/imagenet_train_fixsize480_tau0.15_N3.json", 'w') as f:
    json.dump(data, f, indent=4)
